# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd

# %%
train = pd.read_csv('/content/gdrive/MyDrive/DepressionPrediction/train /train.csv')

# %%
train.head()
# Out:
#      Age  Gender Relationship_status living_with_your_family  \
# 0  21-25  Female   in a relationship                     Yes
# 1  21-25    Male              Single                     Yes
# 2  21-25    Male   in a relationship                     Yes
# 3  21-25    Male   in a relationship                      No
# 4  21-25    Male              Single                     Yes
#
#   current_living_place currently_studying      sleep_time  internet_use_time  \
# 0                 City     Under Graduate       7-9 hours  More than 3 hours
# 1                 City     Under Graduate       7-9 hours  More than 3 hours
# 2              Village     Under Graduate  bellow 7 hours  More than 3 hours
# 3                 City     Under Graduate  bellow 7 hours  More than 3 hours
# 4                 City     Under Graduate       7-9 hours  More than 3 hours
#
#           exercise_time smoker  relationship_with_friends  \
# 0  less than 30 minutes     No                          2
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        520 non-null    object
#  1   Gender                     520 non-null    object
#  2   Relationship_status        520 non-null    object
#  3   living_with_your_family    520 non-null    object
#  4   current_living_place       520 non-null    object
#  5   currently_studying         520 non-null    object
#  6   sleep_time                 520 non-null    object
#  7   internet_use_time          520 non-null    object
#  8   exercise_time              520 non-null    object
#  9   smoker                     520 non-null    object
#  10  relationship_with_friends  520 non-null    int64
#  11  physical_disabilities      520 non-null    object
#  12  depressed                  520 non-null    int64
# dtypes: int64(2), object(11)
# ...

# %%
train.shape
# Out:
# (520, 13)

# %%
train.isnull().sum()
# Out:
# Age                          0
# Gender                       0
# Relationship_status          0
# living_with_your_family      0
# current_living_place         0
# currently_studying           0
# sleep_time                   0
# internet_use_time            0
# exercise_time                0
# smoker                       0
# relationship_with_friends    0
# physical_disabilities        0
# depressed                    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
def bar_chart(feature):
    depressed = train[train['depressed']==1][feature].value_counts()
    normal = train[train['depressed']==0][feature].value_counts()
    df = pd.DataFrame([depressed,normal])
    df.index = ['depressed','normal']
    df.plot(kind='bar',stacked=False, figsize=(10,5))

# %%
bar_chart('Age')

# %%
bar_chart('Gender')

# %%
bar_chart('Relationship_status')

# %%
bar_chart('living_with_your_family')

# %%
bar_chart('current_living_place')

# %%
bar_chart('currently_studying')

# %%
bar_chart('sleep_time')

# %%
bar_chart('internet_use_time')

# %%
bar_chart('Age')

# %%
bar_chart('Age')

# %%
bar_chart('exercise_time')

# %%
bar_chart('relationship_with_friends')

# %%
bar_chart('smoker')

# %%
bar_chart('physical_disabilities')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        520 non-null    object
#  1   Gender                     520 non-null    object
#  2   Relationship_status        520 non-null    object
#  3   living_with_your_family    520 non-null    object
#  4   current_living_place       520 non-null    object
#  5   currently_studying         520 non-null    object
#  6   sleep_time                 520 non-null    object
#  7   internet_use_time          520 non-null    object
#  8   exercise_time              520 non-null    object
#  9   smoker                     520 non-null    object
#  10  relationship_with_friends  520 non-null    int64
#  11  physical_disabilities      520 non-null    object
#  12  depressed                  520 non-null    int64
# dtypes: int64(2), object(11)
# ...

# %%
train_test_data = [train]

# %%
gender_mapping = {"Male": 0, "Female": 1, "Others": 2} 
for dataset in train_test_data:
    dataset['Gender'] = dataset['Gender'].map(gender_mapping)

# %%
age_mapping = {"bellow 11": 0, "11-15": 1, "16-20": 2, "21-25": 3, "26+": 4}
for dataset in train_test_data:
    dataset['Age'] = dataset['Age'].map(age_mapping)

# %%
train.head()
# Out:
#    Age  Gender Relationship_status living_with_your_family  \
# 0    3       1   in a relationship                     Yes
# 1    3       0              Single                     Yes
# 2    3       0   in a relationship                     Yes
# 3    3       0   in a relationship                      No
# 4    3       0              Single                     Yes
#
#   current_living_place currently_studying      sleep_time  internet_use_time  \
# 0                 City     Under Graduate       7-9 hours  More than 3 hours
# 1                 City     Under Graduate       7-9 hours  More than 3 hours
# 2              Village     Under Graduate  bellow 7 hours  More than 3 hours
# 3                 City     Under Graduate  bellow 7 hours  More than 3 hours
# 4                 City     Under Graduate       7-9 hours  More than 3 hours
#
#           exercise_time smoker  relationship_with_friends  \
# 0  less than 30 minutes     No                          2
# ...

# %%
facet = sns.FacetGrid(train, hue="depressed",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.show()

# %%
facet = sns.FacetGrid(train, hue="depressed",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(0.50, 1.5)
# Out:
# (0.5, 1.5)

# %%
facet = sns.FacetGrid(train, hue="depressed",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(0.90, 1.15)
# Out:
# (0.9, 1.15)

# %%
facet = sns.FacetGrid(train, hue="depressed",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(1.25, 1.50)
# Out:
# (1.25, 1.5)

# %%
facet = sns.FacetGrid(train, hue="depressed",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(1.75, 2.0)
# Out:
# (1.75, 2.0)

# %%
facet = sns.FacetGrid(train, hue="depressed",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(0.60, 0.75)
# Out:
# (0.6, 0.75)

# %%
Relationship_status_mapping = {"Single": 0, "in a relationship": 1, "married": 2, "divorced": 3}
for dataset in train_test_data:
    dataset['Relationship_status'] = dataset['Relationship_status'].map(Relationship_status_mapping)

# %%
living_with_your_family_mapping = {"Yes": 0, "No": 1}
for dataset in train_test_data:
    dataset['living_with_your_family'] = dataset['living_with_your_family'].map(living_with_your_family_mapping)

# %%
current_living_place_mapping = {"Village": 0, "City": 1}
for dataset in train_test_data:
    dataset['current_living_place'] = dataset['current_living_place'].map(current_living_place_mapping)

# %%
currently_studying_mapping = {"O Levels(SSC)": 0, "A Levels(HSC)": 1, "Under Graduate": 2, "Graduated": 3, "Masters": 4}
for dataset in train_test_data:
    dataset['currently_studying'] = dataset['currently_studying'].map(currently_studying_mapping)

# %%
sleep_time_mapping = {"bellow 7 hours": 0, "7-9 hours": 1, "more than 9 hours": 2}
for dataset in train_test_data:
    dataset['sleep_time'] = dataset['sleep_time'].map(sleep_time_mapping)

# %%
internet_use_time_mapping = {"bellow 2 hours": 0, "2-3 hours": 1, "More than 3 hours": 2}
for dataset in train_test_data:
    dataset['internet_use_time'] = dataset['internet_use_time'].map(internet_use_time_mapping)

# %%
exercise_time_mapping = {"less than 30 minutes": 0, "30-60 minutes": 1, "more than 60 minutes": 2}
for dataset in train_test_data:
    dataset['exercise_time'] = dataset['exercise_time'].map(exercise_time_mapping)

# %%
smoker_mapping = {"Yes": 0, "No": 1}
for dataset in train_test_data:
    dataset['smoker'] = dataset['smoker'].map(smoker_mapping)

# %%
physical_disabilities_mapping = {"Yes": 0, "No": 1}
for dataset in train_test_data:
    dataset['physical_disabilities'] = dataset['physical_disabilities'].map(physical_disabilities_mapping)

# %%
train.head()
# Out:
#    Age  Gender  Relationship_status  living_with_your_family  \
# 0    3       1                    1                        0
# 1    3       0                    0                        0
# 2    3       0                    1                        0
# 3    3       0                    1                        1
# 4    3       0                    0                        0
#
#    current_living_place  currently_studying  sleep_time  internet_use_time  \
# 0                     1                   2           1                  2
# 1                     1                   2           1                  2
# 2                     0                   2           0                  2
# 3                     1                   2           0                  2
# 4                     1                   2           1                  2
#
#    exercise_time  smoker  relationship_with_friends  physical_disabilities  \
# ...

# %%
train.isnull().sum()
# Out:
# Age                          0
# Gender                       0
# Relationship_status          0
# living_with_your_family      0
# current_living_place         0
# currently_studying           0
# sleep_time                   0
# internet_use_time            0
# exercise_time                0
# smoker                       0
# relationship_with_friends    0
# physical_disabilities        0
# depressed                    0
# dtype: int64

# %%
# (X_TRAIN->train_x, Y_TRAIN->target_y), X_TEST, Y_TEST
train_x = train.drop(['Age','depressed','currently_studying'], axis=1) 
 
target_y = train['depressed']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train_x, target_y, test_size=.30, random_state=42)
print("X_train: ", X_train.shape)
print("X_test: ", X_test.shape)
print("y_train: ", y_train.shape)
print("y_test: ", y_test.shape)
print(y_test)

y_test.value_counts()
# Out:
# X_train:  (364, 10)
# X_test:  (156, 10)
# y_train:  (364,)
# y_test:  (156,)
# 275    1
# 93     1
# 6      1
# 167    1
# 90     1
#       ..
# 24     0
# 17     0
# 245    0
# 66     0
# 229    0
# Name: depressed, Length: 156, dtype: int64
# 0    79
# 1    77
# Name: depressed, dtype: int64

# %%
# Importing Classifier Modules
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(y_test, y_pred))
# Out:
# [[52 27]
#  [33 44]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.66      0.63        79
#            1       0.62      0.57      0.59        77
#
#     accuracy                           0.62       156
#    macro avg       0.62      0.61      0.61       156
# weighted avg       0.62      0.62      0.61       156

# %%
from sklearn.metrics import accuracy_score as a1
print(a1(y_test, y_pred)*100)
# Out:
# 61.53846153846154

# %% [markdown]
# **RandomForestClassifier**

# %%
dt = RandomForestClassifier()
dt.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = dt.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(y_test, y_pred))
# Out:
# [[49 30]
#  [28 49]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.62      0.63        79
#            1       0.62      0.64      0.63        77
#
#     accuracy                           0.63       156
#    macro avg       0.63      0.63      0.63       156
# weighted avg       0.63      0.63      0.63       156

# %%
from sklearn.metrics import accuracy_score as a2
print(a2(y_test, y_pred)*100)
# Out:
# 62.82051282051282

# %% [markdown]
# **SVM classifier**

# %%
from sklearn.svm import SVC

# %%
dt = SVC()
dt.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred = dt.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(y_test, y_pred))
# Out:
# [[55 24]
#  [23 54]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.70      0.70        79
#            1       0.69      0.70      0.70        77
#
#     accuracy                           0.70       156
#    macro avg       0.70      0.70      0.70       156
# weighted avg       0.70      0.70      0.70       156

# %%
from sklearn.metrics import accuracy_score as a3
print(a3(y_test, y_pred)*100)
# Out:
# 69.87179487179486

# %% [markdown]
# **Gradient Boosting Classifier**

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
dt = GradientBoostingClassifier()
dt.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred = dt.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(y_test, y_pred))
# Out:
# [[52 27]
#  [26 51]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.66      0.66        79
#            1       0.65      0.66      0.66        77
#
#     accuracy                           0.66       156
#    macro avg       0.66      0.66      0.66       156
# weighted avg       0.66      0.66      0.66       156

# %%
from sklearn.metrics import accuracy_score as a4
print(a4(y_test, y_pred)*100)
# Out:
# 66.02564102564102

# %% [markdown]
# **Logistic Regression classifier**

# %%
from sklearn.linear_model import LogisticRegression

# %%
dt = LogisticRegression()
dt.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = dt.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(y_test, y_pred))
# Out:
# [[54 25]
#  [25 52]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.68      0.68        79
#            1       0.68      0.68      0.68        77
#
#     accuracy                           0.68       156
#    macro avg       0.68      0.68      0.68       156
# weighted avg       0.68      0.68      0.68       156

# %%
from sklearn.metrics import accuracy_score as a5
print(a5(y_test, y_pred)*100)
# Out:
# 67.94871794871796

# %% [markdown]
# **Nearest Neighbors**

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
dt = KNeighborsClassifier()
dt.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = dt.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(y_test, y_pred))
# Out:
# [[55 24]
#  [34 43]]

# %%
from sklearn.metrics import accuracy_score as a6
print(a6(y_test, y_pred)*100)
# Out:
# 62.82051282051282
