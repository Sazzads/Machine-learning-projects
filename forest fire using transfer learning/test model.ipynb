# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

import tensorflow_hub as hub
import tensorflow_datasets as tfds

from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
print(tf. __version__)
# Out:
# 2.9.2

# %%
model = tf.keras.models.load_model('/content/drive/MyDrive/DEFENCE/implement 2/edited code/model/model.h5')
print("model has been loaded")
# Out:
# model has been loaded

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import img_to_array,load_img

# %%
path0="/content/drive/MyDrive/DEFENCE/tessstpic.png"
#load_img(path0,target_size=(300,300))

# %%
def model_predict(img_path, model):
    print(img_path)
    img = image.load_img(img_path, target_size=(224, 224))

    # Preprocessing the image
    x = image.img_to_array(img)
    # x = np.true_divide(x, 255)
    ## Scaling
    x=x/255
    x = np.expand_dims(x, axis=0)
   

    # Be careful how your trained model deals with the input
    # otherwise, it won't make correct prediction!
   # x = preprocess_input(x)

    preds = model.predict(x)
    preds=np.argmax(preds, axis=1)
    l=['fire','fog','nonfire','smoke']
    print('',l[int(preds)].upper())

# %%
file_path="/content/drive/MyDrive/DEFENCE/tessstpic.png"
load_img(path0,target_size=(224,224))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F25539E1910>

# %%
preds = model_predict(file_path, model)
result=preds
load_img(path0,target_size=(224,224))
# Out:
# /content/drive/MyDrive/DEFENCE/tessstpic.png
# 1/1 [==============================] - 4s 4s/step
#  FIRE
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F25521987C0>
